# %% [markdown]
# <a href="https://colab.research.google.com/github/Marisol00278/Proyectos_de_Python/blob/main/9_Sistema_de_Tarifas_de_Transporte.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Sistema de tarifas de transporte por edad y distancia**

# %% [markdown]
# Un sistema de transporte cobra según la edad del pasajero y la distancia recorrida:
#
# Menores de 6 años: Viajan gratis.
# De 6 a 18 años:
# Hasta 20 km: $1.50
# Más de 20 km: $2.50
# Mayores de 18:
# Hasta 20 km: $2.50
# Más de 20 km: $4.00
# Crea un programa que reciba la edad y distancia, y muestre el valor a pagar.

# %%
# Programa para calcular el costo del pasaje según edad y distancia

# Entrada de datos
edad = int(input("Ingrese la edad del pasajero: "))
distancia = float(input("Ingrese la distancia recorrida en km: "))

# Cálculo del costo
if edad < 6:
    costo = 0
elif edad <= 18:
    if distancia <= 20:
        costo = 1.50
    else:
        costo = 2.50
else:  # Mayores de 18
    if distancia <= 20:
        costo = 2.50
    else:
        costo = 4.00

# Resultado
if costo == 0:
    print("Viaja gratis.")
else:
    print(f"El valor a pagar es: ${costo:.2f}")
# Out:
# Ingrese la edad del pasajero: 15
# Ingrese la distancia recorrida en km: 36
# El valor a pagar es: $2.50
